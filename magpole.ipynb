# %%
import fastf1
fastf1.Cache.enable_cache('/Users/shivanireddy/Desktop/dataclasses/datastudio/project2/cache')  
from fastf1 import plotting
from fastf1 import utils

# %%
quali = fastf1.get_session(2022, 'Brazil', 'Q')

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import numpy as np
import pandas as pd

# %%
quali.load()
# Out:
# core           INFO 	Loading data for São Paulo Grand Prix - Qualifying [v2.3.0]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# /Users/shivanireddy/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/fastf1/core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# /Users/shivanireddy/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/fastf1/core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# ...

# %%
mag = 'MAG'
ver = 'VER'
rus = 'RUS'

# %%
quali.laps
# Out:
#                       Time DriverNumber                LapTime  LapNumber  \
# 0   0 days 00:15:27.758000           20                    NaT          1
# 1   0 days 00:16:47.639000           20 0 days 00:01:19.881000          2
# 2   0 days 00:18:07.428000           20 0 days 00:01:19.789000          3
# 3   0 days 00:19:43.453000           20 0 days 00:01:36.025000          4
# 4   0 days 00:21:42.196000           20 0 days 00:01:58.743000          5
# ..                     ...          ...                    ...        ...
# 411 0 days 00:26:59.248000           47 0 days 00:01:33.583000          8
# 412 0 days 00:30:00.064000           47                    NaT          9
# 413 0 days 00:31:20.103000           47 0 days 00:01:20.039000         10
# 414 0 days 00:32:36.464000           47 0 days 00:01:16.361000         11
# 415 0 days 00:34:16.386000           47 0 days 00:01:39.922000         12
#
#                 PitOutTime              PitInTime            Sector1Time  \
# ...

# %%
laps_mag = quali.laps.pick_driver(mag)
laps_ver = quali.laps.pick_driver(ver)
laps_rus = quali.laps.pick_driver(rus)

# %%
laps_mag
# Out:
#                      Time DriverNumber                LapTime  LapNumber  \
# 0  0 days 00:15:27.758000           20                    NaT          1
# 1  0 days 00:16:47.639000           20 0 days 00:01:19.881000          2
# 2  0 days 00:18:07.428000           20 0 days 00:01:19.789000          3
# 3  0 days 00:19:43.453000           20 0 days 00:01:36.025000          4
# 4  0 days 00:21:42.196000           20 0 days 00:01:58.743000          5
# 5  0 days 00:23:00.619000           20 0 days 00:01:18.423000          6
# 6  0 days 00:24:25.036000           20 0 days 00:01:24.417000          7
# 7  0 days 00:25:46.398000           20 0 days 00:01:21.362000          8
# 8  0 days 00:27:22.070000           20 0 days 00:01:35.672000          9
# 9  0 days 00:30:09.076000           20                    NaT         10
# 10 0 days 00:31:24.831000           20 0 days 00:01:15.755000         11
# 11 0 days 00:32:38.785000           20 0 days 00:01:13.954000         12
# ...

# %%
fastest_mag = laps_mag.pick_fastest()
fastest_ver = laps_ver.pick_fastest()
fastest_rus = laps_rus.pick_fastest()
fastest_mag
fastest_ver
# Out:
# Time                      0 days 01:04:44.312000
# DriverNumber                                   1
# LapTime                   0 days 00:01:11.877000
# LapNumber                                     22
# PitOutTime                                   NaT
# PitInTime                                    NaT
# Sector1Time               0 days 00:00:18.331000
# Sector2Time               0 days 00:00:36.607000
# Sector3Time               0 days 00:00:16.939000
# Sector1SessionTime        0 days 01:03:50.766000
# Sector2SessionTime        0 days 01:04:27.373000
# Sector3SessionTime        0 days 01:04:44.312000
# SpeedI1                                    323.0
# SpeedI2                                    260.0
# SpeedFL                                    324.0
# SpeedST                                    327.0
# IsPersonalBest                              True
# Compound                                    SOFT
# TyreLife                                     2.0
# ...

# %%
telemetry_mag = fastest_mag.get_telemetry().add_distance()
telemetry_ver = fastest_ver.get_telemetry().add_distance()
telemetry_rus = fastest_rus.get_telemetry().add_distance()
# Out:
# /Users/shivanireddy/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/fastf1/core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time
# /Users/shivanireddy/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/fastf1/core.py:378: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data_slice.loc[:, 'Time'] = data_slice['SessionTime'] - start_time
# ...

# %%
team_mag = fastest_mag['Team']
team_ver = fastest_ver['Team']
team_rus = fastest_rus['Team']

# %%
plt.rcParams['figure.figsize'] = [15,15]

fig, ax = plt.subplots(7, gridspec_kw={'height_ratios': [1, 3, 2, 1, 1, 2, 1]})

ax[0].title.set_text('plot title')

delta_time, ref_tel, compare_tel = utils.delta_time(fastest_mag, fastest_ver)

ax[0].plot(ref_tel['Distance'], delta_time)
ax[0].axhline(0)
ax[0].set(ylabel=f"Gap to {mag} (s)")

ax[1].plot(telemetry_mag['Distance'], telemetry_mag['Speed'], label=mag, color='red')
ax[1].plot(telemetry_ver['Distance'], telemetry_ver['Speed'], label=ver, color=fastf1.plotting.team_color(team_ver))
ax[1].set(ylabel='Speed')
ax[1].legend(loc="lower right")


# # Throttle trace
# ax[2].plot(telemetry_mag['Distance'], telemetry_mag['Throttle'], label=mag, color='red')
# ax[2].plot(telemetry_ver['Distance'], telemetry_ver['Throttle'], label=ver, color=fastf1.plotting.team_color(team_ver))
# ax[2].set(ylabel='Throttle')

# # Brake trace
# ax[3].plot(telemetry_mag['Distance'], telemetry_mag['Brake'], label=mag, color='red')
# ax[3].plot(telemetry_ver['Distance'], telemetry_ver['Brake'], label=ver, color=fastf1.plotting.team_color(team_ver))
# ax[3].set(ylabel='Brake')

# # Gear trace
# ax[4].plot(telemetry_mag['Distance'], telemetry_mag['nGear'], label=mag, color='red')
# ax[4].plot(telemetry_ver['Distance'], telemetry_ver['nGear'], label=ver, color=fastf1.plotting.team_color(team_ver))
# ax[4].set(ylabel='Gear')

# # RPM trace
# ax[5].plot(telemetry_mag['Distance'], telemetry_mag['RPM'], label=mag, color='red')
# ax[5].plot(telemetry_ver['Distance'], telemetry_ver['RPM'], label=ver, color=fastf1.plotting.team_color(team_ver))
# ax[5].set(ylabel='RPM')

# # DRS trace
# ax[6].plot(telemetry_mag['Distance'], telemetry_mag['DRS'], label=mag, color='red')
# ax[6].plot(telemetry_ver['Distance'], telemetry_ver['DRS'], label=ver, color=fastf1.plotting.team_color(team_ver))
# ax[6].set(ylabel='DRS')
# ax[6].set(xlabel='Lap distance (meters)')


# Hide x labels and tick labels for top plots and y ticks for right plots.
for a in ax.flat:
    a.label_outer()

#save as svg
plt.savefig('magpole.svg', format='svg', dpi=1200)
# Out:
# /Users/shivanireddy/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/fastf1/core.py:584: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ret.loc[:, ch] = ret.loc[:, ch].ffill().ffill().bfill()
# /Users/shivanireddy/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/fastf1/core.py:508: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   merged.loc[:, col] = merged.loc[:, col].astype(dtype_map[col])
# ...

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%R
# require('tidyverse')
# Out:
# callbacks    WARNING 	R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
import pandas as pd
